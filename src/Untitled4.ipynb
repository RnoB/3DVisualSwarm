# %%
import visualProjector as vp
import imp
import matplotlib.pyplot as plt
import numpy as np
import random
from imp import reload
from mathutils import Vector
reload(vp)
# Out:
# <module 'visualProjector' from 'C:\\Users\\renaud\\Documents\\3DVisualSwarm\\src\\visualProjector.py'>

# %%
size = 20
proj = vp.Projector(size = size)
# Out:
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)

# %%
X = np.linspace(-np.pi,np.pi,4)
R =3

X = np.array([0,.5,1,1.5])*np.pi
step=0.1
for j in range(0,10):
    proj = vp.Projector(size = size)
    for beta in X:
        alpha = beta + j*step
        #proj = vp.Projector(size = size)
        proj.addObject(R*np.cos(alpha),R*np.sin(alpha),0)
        
        #proj.addObject(0,0,3*np.sin(alpha))
        #proj.addObject(0,0,3*np.cos(alpha))
    proj.render()
    fig=plt.figure()
    plt.imshow(proj.image())
# Out:
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# ...

# %%
def equirectangularToDirection(u,v):
    rang = [-2*np.pi, np.pi, -np.pi, np.pi/2.0]
    phi = rang[0] * u + rang[1];
    theta = rang[2] * v + rang[3];
    return phi,theta

# %%
size = 21
u = np.linspace(0,1,size)

# %%
plt.plot(u,equirectangularToDirection(u,0)[0]/np.pi,'o')

# %%
equirectangularToDirection(.5,.5)
# Out:
# (0.0, 0.0)

# %%
u
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
equirectangular_range_to_direction(0,0,rang)
# Out:
# (3.141592653589793, 1.5707963267948966)

# %%
equirectangular_range_to_direction(1,0,rang)
# Out:
# (-3.141592653589793, 1.5707963267948966)

# %%
u = np.linspace(0,1,4)

# %%
u
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
dir(vp.bpy.data.images['Viewer Node'])
# Out:
# ['__doc__',
#  '__module__',
#  '__slots__',
#  'alpha_mode',
#  'animation_data_clear',
#  'animation_data_create',
#  'asset_data',
#  'bindcode',
#  'bl_rna',
#  'buffers_free',
#  'channels',
#  'colorspace_settings',
#  'copy',
#  'depth',
#  'display_aspect',
#  'evaluated_get',
#  'file_format',
#  'filepath',
#  'filepath_from_user',
#  'filepath_raw',
#  'frame_duration',
#  'generated_color',
#  'generated_height',
#  'generated_type',
#  'generated_width',
#  'gl_free',
#  'gl_load',
#  'gl_touch',
#  'has_data',
#  'is_dirty',
#  'is_embedded_data',
#  'is_evaluated',
#  'is_float',
#  'is_library_indirect',
#  'is_multiview',
#  'is_stereo_3d',
#  'library',
#  'make_local',
#  'name',
#  'name_full',
#  'original',
#  'override_create',
#  'override_library',
#  'override_template_create',
#  'pack',
#  'packed_file',
#  'packed_files',
#  'pixels',
#  'preview',
#  'reload',
#  'render_slots',
#  'resolution',
#  'rna_type',
#  'save',
#  'save_render',
#  'scale',
# ...

# %%
X = np.linspace(-np.pi,np.pi,4)
R =3

X = [np.pi,np.pi/2.0,0,-np.pi/2.0]#np.array([0,.5,1,1.5])*np.pi
print(X)

proj = vp.Projector(size = 100)
for alpha in X:

    #proj = vp.Projector(size = size)
    proj.addObject(R*np.cos(alpha),R*np.sin(alpha),0)

    #proj.addObject(0,0,3*np.sin(alpha))
    #proj.addObject(0,0,3*np.cos(alpha))
proj.render()
fig=plt.figure()
plt.imshow(proj.image())
# Out:
# [3.141592653589793, 1.5707963267948966, 0, -1.5707963267948966]
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)

# %%
scene = vp.bpy.context.scene
obj = vp.bpy.data.objects['agent']
cam = vp.bpy.data.objects['Camera']

# %%
verts = (vert.co for vert in obj.data.vertices)
coords_2d = [vp.bpy_extras.object_utils.world_to_camera_view(scene, cam, coord) for coord in verts]

# %%
coords_2d
# Out:
# [Vector((6.05555534362793, 63548148.0, 4.371138828673793e-08)),
#  Vector((-31774072.0, 3.2777771949768066, -4.3711395392165286e-08)),
#  Vector((-10591356.0, -0.42592599987983704, 1.3113417196564114e-07)),
#  Vector((-2.277777910232544, 63548152.0, -4.371138473402425e-08))]

# %%
for vert in obj.data.vertices:
    print(vert.co) 
    
    print(vp.bpy_extras.object_utils.world_to_camera_view(scene, cam, vert.co*10))
# Out:
# <Vector (-0.0000, -0.0000, 1.0000)>
# <Vector (6.0556, 63548148.0000, 0.0000)>
# <Vector (-0.0000, -1.0000, -0.0000)>
# <Vector (-31774070.0000, 3.2778, -0.0000)>
# <Vector (0.0000, 1.0000, -0.0000)>
# <Vector (-10591355.0000, -0.4259, 0.0000)>
# <Vector (0.0000, -0.0000, -1.0000)>
# <Vector (-2.2778, 63548152.0000, -0.0000)>

# %%
dir(cam)
# Out:
# ['__doc__',
#  '__module__',
#  '__slots__',
#  'active_material',
#  'active_material_index',
#  'active_shape_key',
#  'active_shape_key_index',
#  'animation_data',
#  'animation_data_clear',
#  'animation_data_create',
#  'animation_visualization',
#  'asset_data',
#  'bl_rna',
#  'bound_box',
#  'cache_release',
#  'calc_matrix_camera',
#  'camera_fit_coords',
#  'children',
#  'closest_point_on_mesh',
#  'collision',
#  'color',
#  'constraints',
#  'convert_space',
#  'copy',
#  'cycles',
#  'cycles_visibility',
#  'data',
#  'delta_location',
#  'delta_rotation_euler',
#  'delta_rotation_quaternion',
#  'delta_scale',
#  'dimensions',
#  'display',
#  'display_bounds_type',
#  'display_type',
#  'empty_display_size',
#  'empty_display_type',
#  'empty_image_depth',
#  'empty_image_offset',
#  'empty_image_side',
#  'evaluated_get',
#  'face_maps',
#  'field',
#  'find_armature',
#  'generate_gpencil_strokes',
#  'grease_pencil_modifiers',
#  'hide_get',
#  'hide_render',
# ...

# %%
cam.camera_fit_coords()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-278cfcd05bc5> in <module>
# ----> 1 cam.camera_fit_coords()
#
# TypeError: Object.camera_fit_coords(): required parameter "depsgraph" not specified

# %%
vp.bpy_extras.object_utils.world_to_camera_view(scene, cam,Vector([10,10,0]))
# Out:
# Vector((-0.8888888359069824, 0.49999988079071045, 10.0))

# %%
X = np.linspace(-np.pi,np.pi,200)
R= 5
uv2 = []
uv3 = []
for alpha in X:
    x = R*np.cos(alpha)
    y = R*np.sin(alpha)
    uv = vp.bpy_extras.object_utils.world_to_camera_view(scene, cam,Vector([x,y,0]))
    uv2.append([uv.x,uv.y])
    uv3.append(eqToUV([x,y]))
uv2=np.array(uv2)

# %%
plt.plot(uv3)
#plt.ylim([-1,1])

# %%
rang
def eqToUV(dir):
    u = (np.arctan2(dir[1],dir[0])-rang[1]) / rang[0]
    return u

# %%
uv3
# Out:
# [1.0,
#  0.9949748743718594,
#  0.9899497487437187,
#  0.9849246231155778,
#  0.9798994974874372,
#  0.9748743718592965,
#  0.9698492462311558,
#  0.9648241206030151,
#  0.9597989949748743,
#  0.9547738693467336,
#  0.949748743718593,
#  0.9447236180904524,
#  0.9396984924623115,
#  0.9346733668341708,
#  0.9296482412060302,
#  0.9246231155778895,
#  0.9195979899497486,
#  0.914572864321608,
#  0.9095477386934673,
#  0.9045226130653267,
#  0.8994974874371859,
#  0.8944723618090453,
#  0.8894472361809045,
#  0.8844221105527638,
#  0.8793969849246231,
#  0.8743718592964824,
#  0.8693467336683416,
#  0.864321608040201,
#  0.8592964824120604,
#  0.8542713567839196,
#  0.8492462311557789,
#  0.8442211055276383,
#  0.8391959798994975,
#  0.8341708542713567,
#  0.8291457286432161,
#  0.8241206030150754,
#  0.8190954773869346,
#  0.8140703517587939,
#  0.8090452261306533,
#  0.8040201005025126,
#  0.7989949748743718,
#  0.7939698492462312,
#  0.7889447236180904,
#  0.7839195979899497,
# ...

# %%
plt.imshow(proj.image())

# %%
np.shape(proj.sine.sinThetaIm)
# Out:
# (51, 101)
