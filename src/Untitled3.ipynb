# %%
import visualProjector as vp
import imp
import matplotlib.pyplot as plt
import numpy as np
import random
imp.reload(vp)
# Out:
# <module 'visualProjector' from 'C:\\Users\\renaud\\Documents\\3DVisualSwarm\\src\\visualProjector.py'>

# %%
size = 1920
proj = vp.Projector(size = size)
# Out:
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)

# %%
for k in range(0,10):
    proj.addObject(10*random.random(),10*random.random(),10*random.random())

# %%
proj.computeAllVisualField()

# %%
proj.derivateAllVisualField()

# %%
plt.imshow((proj.allVisualFieldDPhi*proj.sine.sinThetaAll)[:,:,1],cmap="PiYG")

# %%
plt.imshow(proj.allVisualField[:,:,1])

# %%
plt.imshow(np.abs(proj.allVisualFieldDTheta[:,:,1])+np.abs(proj.allVisualFieldDPhi[:,:,1]),cmap="PiYG")

# %%
plt.imshow((np.roll(proj.allVisualField[:,:,:],1,1)-np.roll(proj.allVisualField[:,:,:],-1,1))[:,:,4])

# %%
plt.imshow((np.roll(proj.allVisualField[:,:,4],1,1)-np.roll(proj.allVisualField[:,:,4],-1,1)))

# %%
plt.imshow(proj.allVisualField[:-2,:,4]-proj.allVisualField[2:,:,4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-397c94ff99f1> in <module>
# ----> 1 plt.imshow(proj.allVisualField[:-2,:,4]-proj.allVisualField[2:,:,4])
#
# NameError: name 'plt' is not defined

# %%
plt.imshow((proj.allVisualField[:-2,:,:]-proj.allVisualField[2:,:,:])[:,:,4])

# %%
np.shape(np.pad((proj.allVisualField[:-2,:,:]-proj.allVisualField[2:,:,:]),((1,1),(0,0),(0,0))))

# %%
np.shape((proj.allVisualField))

# %%
np.shape(proj.allVisualField[:-2,:,:]-proj.allVisualField[2:,:,:])

# %%
plt.imshow(np.pad((proj.allVisualField[:-2,:,:]-proj.allVisualField[2:,:,:]),((1,1),(0,0),(0,0)),'constant', constant_values=0)[:,:,4])

# %%
np.shape(np.array([proj.sine.phi2d]*3).transpose((1,2,0)))
# Out:
# (33, 64, 3)

# %%
np.shape(proj.allVisualField)
# Out:
# (33, 64, 10)
