# %%
import visualProjector as vp
import matplotlib.pyplot as plt
import numpy as np
from imp import reload
import random


reload(vp)
# Out:
# <module 'visualProjector' from 'C:\\Users\\renaud\\Documents\\3DVisualSwarm\\src\\visualProjector.py'>

# %%
scene = vp.Scene()
scene.addObject((0,0,0),(0,0,0),1)
scene.addObject((2,0,0),(0,0,0),1)
scene.addObject((0,2,0),(0,0,0),1)
# Out:
# 2

# %%
for k in range(0,scene.getLength()):
    plt.figure()
    plt.imshow(scene.computeVisualField(k))

# %%
for k in range(0,10):
    plt.figure()
    scene.rotateObject(0,(1,1,1))
    plt.imshow(scene.computeVisualField(0))

# %%
(scene.rotation+np.pi)%(2*np.pi)-np.pi
# Out:
# 0.0

# %%
np.hstack((np.arange(0,3).reshape(3,1),scene.position,scene.rotation))
# Out:
# array([[ 0.,  0.,  0.,  0., 10., 10., 10.],
#        [ 1.,  2.,  0.,  0.,  0.,  0.,  0.],
#        [ 2.,  0.,  2.,  0.,  0.,  0.,  0.]])

# %%
np.shape(np.array(np.arange(0,3)))
# Out:
# (3,)
