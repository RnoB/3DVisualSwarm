# %%
import visualProjector as vp
import matplotlib.pyplot as plt
import numpy as np
from imp import reload
import random


reload(vp)
# Out:
# <module 'visualProjector' from 'C:\\Users\\renaud\\Documents\\3DVisualSwarm\\src\\visualProjector.py'>

# %%
scene = vp.Scene()
for k in range(0,10):
    scene.addObject((10*random.random(),10*random.random(),10*random.random()),(0,0,2*np.pi*random.random()))

# %%
plt.imshow(scene.computeVisualField(3))
# Out:
# [[ 5.76732914 -0.16852811  0.50726071]
#  [ 5.54122282 -0.794768    0.53580416]
#  [ 7.87192387 -0.62696677 -0.23008994]
#  [ 2.58774202 -0.61559962  0.08895085]
#  [ 9.76403938 -0.78383937  0.81917669]
#  [ 6.40390706 -0.55147695  0.39938468]
#  [ 5.37553184  1.12907744  1.3310316 ]
#  [ 9.91293814 -0.60922437 -0.05994526]
#  [ 8.62989611 -0.89613856  0.41391498]]

# %%
scene.V
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-dbbecd9d8f0e> in <module>
# ----> 1 scene.V
#
# AttributeError: 'Scene' object has no attribute 'V'

# %%
# Out:
# [[ 4.64056951  2.55819523 -0.01933335]
#  [ 2.93886953  0.31370491 -0.03862705]
#  [ 6.76545822 -1.48880692  0.89581949]
#  [ 7.64621903 -1.6110779   0.76975118]
#  [ 7.82399667 -2.14452796  0.25799236]
#  [ 4.65828167  2.36774777 -0.30047381]
#  [ 7.09911805 -1.84862515  0.78361275]
#  [ 8.06760459 -1.2022533   0.99873885]
#  [ 6.07786976 -0.21493544  1.1636584 ]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-ef4c4b67b08b> in <module>
# ----> 1 scene.computeVisualField(3)
#
# ~\Documents\3DVisualSwarm\src\visualProjector.py in computeVisualField(self, k)
#     184         for k in range(0,np.shape(X)[0]):
#     185             #try:
# --> 186                 vIdxTmp = drawSphere(Xs[k,:],1,self.size)
#     187             #except:
#     188                 print(Xs[k,:])
#
# NameError: name 'drawSphere' is not defined

# %%
k=3
np.delete(scene.position - scene.position[k,:],k,0)
# Out:
# array([[-3.87227675,  2.55583838, -0.08971217],
#        [ 2.79335814,  0.90621411, -0.11349164],
#        [ 0.34622976, -4.2133928 ,  5.28193819],
#        [-0.22111126, -5.48617252,  5.32143648],
#        [-4.10608444, -6.35374898,  1.99621352],
#        [-3.18246332,  3.1097642 , -1.37872477],
#        [-1.37923779, -4.835951  ,  5.01086401],
#        [ 1.57342225, -4.07423964,  6.78315248],
#        [ 2.35135358, -0.5133183 ,  5.58105201]])

# %%
try:
    bodySize
except:
    print('nop')
# Out:
# nop

# %%
scene = vp.Scene()
scene.addObject((0,0,0),(0,0,0),1)
scene.addObject((2,0,0),(0,0,0),1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9464e4a6f62d> in <module>
# ----> 1 scene = vp.Scene()
#       2 scene.addObject((0,0,0),(0,0,0),1)
#       3 scene.addObject((2,0,0),(0,0,0),1)
#
# NameError: name 'vp' is not defined
